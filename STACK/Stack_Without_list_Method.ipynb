# %%
#Stack class Without List Methods
class STACK:
    
    #construction function
    def __init__(self):
        self.size = int(input('ENER THE SIZE OF SACK: '))
        self.stack=[None]*self.size
    
    #Insertion Method (Inserting element in end)
    def Insert(self,data):
        if st.Lenth() >= self.size:
            print('\nSTACK IS FULL')
        else:
            data=int(input('\nPlease Enter the data:  '))
            self.stack[self.Lenth()]=data
    
    #Deletion Method (Deleting element in end)
    def Delete(self):
        if self.Lenth() == 0:
            print('\nSTACK IS EMPTY')
        else:
            self.stack[self.Lenth()-1]=None
    
    #Lenth Method (Finding the lenght of stack)
    def Lenth(self):
        count=0
        for i in self.stack:
            if i is not None:
                count+=1
        return count
    
    #Print MEthod (Printing the stack)
    def Print(self):
        if self.Lenth() == 0:
                print('\nSTACK IS EMTPY')
        else:
            out=''
            for i in self.stack:
                if i is not None:
                    out=out+str(i)+" "
            print('\nSTACK: ',out)
    
    #Clean Method
    def Clean(self):
        for i in range(self.Lenth()):
            self.stack[i]=None

    #Class Object
    st=STACK()
    
    #Option Loop
    loop=-1
    while loop == -1:
        select=int(input('\nPlease Select the Action:\n1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  '))
        if select == 1:
            st.Insert()
        elif select == 2:
            st.Delete()
        elif select == 3:
            st.Print()
        elif select == 4:
            st.Clean()
        elif select == 5:
            print(st.Length())
        elif select == 6:
            loop = 1
            print('\nThankYou!!!!')
        else:
            print('\nINVALID CREDENTIAL')
