# %%
#Stack class Without List Methods
class STACK:
    
    #construction function
    def __init__(self):
        self.size = int(input('ENER THE SIZE OF SACK: '))
        self.stack=[]
    
    #Insertion Method (Inserting element in end)
    def Insert(self):
        if st.Length() >= self.size:
            print('\nSTACK IS FULL')
        else:
            data=int(input('\nPlease Enter the data:  '))
            self.stack[self.Length():]=[data]
    
    #Deletion Method (Deleting element in end)
    def Delete(self):
        if self.Length() == 0:
            print('\nSTACK IS EMPTY')
        else:
            self.stack=self.stack[:self.Length()-1]
    
    #Lenth Method (Finding the lenght of stack)
    def Length(self):
        count=0
        for i in self.stack:
            count+=1
        return count
    
    #Print MEthod (Printing the stack)
    def Print(self):
        if self.Length() == 0:
                print('\nSTACK IS EMTPY')
        else:
            out=''
            for i in self.stack:
                out=out+str(i)+" "
            print('\nSTACK: ',out)
    
    #Clean Method
    def Clean(self):
        for i in range(self.Length()):
            self.stack=[]

if __name__ == "__main__":

    #Class Object
    st=STACK()

    #Option Loop
    loop=-1
    while loop == -1:
        select=int(input('\nPlease Select the Action:\n1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  '))
        if select == 1:
            st.Insert()
        elif select == 2:
            st.Delete()
        elif select == 3:
            st.Print()
        elif select == 4:
            print(st.Length())
        elif select == 5:
            st.Clean()
        elif select == 6:
            loop = 1
            print('\nThankYou!!!!')
        else:
            print('\nINVALID CREDENTIAL')
# Out:
# ENER THE SIZE OF SACK: 3
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  1
#
# Please Enter the data:  5
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  1
#
# Please Enter the data:  9
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  1
#
# Please Enter the data:  6
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  1
#
# STACK IS FULL
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  3
#
# STACK:  5 9 6
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  2
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  3
#
# STACK:  5 9
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  5
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  3
#
# STACK IS EMTPY
#
# Please Select the Action:
# 1.Insert 2.Delete 3.Print 4.Num_ele 5.Clear 6.Exit:  6
#
# ThankYou!!!!
